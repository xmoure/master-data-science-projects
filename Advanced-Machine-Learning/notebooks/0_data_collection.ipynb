# %% [markdown]
# ###

# %%
import pandas as pd

df1=pd.read_csv("part-00000-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv")
df2=pd.read_csv("part-00001-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv")
df3=pd.read_csv("part-00002-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv")
df4=pd.read_csv("part-00003-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv")
df5=pd.read_csv("part-00004-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv")
df6=pd.read_csv("part-00005-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv")
df7=pd.read_csv("part-00006-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv")
df8=pd.read_csv("part-00007-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv")
df9=pd.read_csv("part-00008-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv")
df10=pd.read_csv("part-00009-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv")
df11=pd.read_csv("part-00010-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv")
df12=pd.read_csv("part-00011-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv")
df13=pd.read_csv("part-00012-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv")
df14=pd.read_csv("part-00013-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv")
df15=pd.read_csv("part-00014-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv")
df16=pd.read_csv("part-00015-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv")

# %%
df1.head()
# Out:
#    flow_duration  Header_Length  Protocol Type  Duration         Rate  \
# 0       0.000000          54.00           6.00     64.00     0.329807
# 1       0.000000          57.04           6.33     64.00     4.290556
# 2       0.000000           0.00           1.00     64.00    33.396799
# 3       0.328175       76175.00          17.00     64.00  4642.133010
# 4       0.117320         101.73           6.11     65.91     6.202211
#
#          Srate  Drate  fin_flag_number  syn_flag_number  rst_flag_number  ...  \
# 0     0.329807    0.0              1.0              0.0              1.0  ...
# 1     4.290556    0.0              0.0              0.0              0.0  ...
# 2    33.396799    0.0              0.0              0.0              0.0  ...
# 3  4642.133010    0.0              0.0              0.0              0.0  ...
# 4     6.202211    0.0              0.0              1.0              0.0  ...
#
#          Std  Tot size           IAT  Number   Magnitue     Radius  \
# ...

# %%
print(len(df1['label'].unique()))
print(len(df2['label'].unique()))
print(len(df3['label'].unique()))
print(len(df4['label'].unique()))
# Out:
# 34
# 34
# 34
# 34

# %%
# Remapping labels accordingly to generalise classification
# conforms with Madhav's remapping
# 34 unique labels to 8 general labels
remap_labels = {
    'DDoS-RSTFINFlood': 'DDoS',
    'DDoS-ICMP_Flood': 'DDoS',
    'DDoS-SynonymousIP_Flood': 'DDoS',
    'DDoS-SYN_Flood': 'DDoS',
    'DDoS-PSHACK_Flood': 'DDoS',
    'DDoS-TCP_Flood': 'DDoS',
    'DDoS-UDP_Flood': 'DDoS',
    'DDoS-ACK_Fragmentation': 'DDoS',
    'DDoS-ICMP_Fragmentation': 'DDoS',
    'DDoS-UDP_Fragmentation': 'DDoS',
    'DDoS-HTTP_Flood': 'DDoS',
    'DDoS-SlowLoris': 'DDoS',

    'DoS-TCP_Flood': 'DoS',
    'DoS-UDP_Flood': 'DoS',
    'DoS-SYN_Flood': 'DoS',
    'DoS-HTTP_Flood': 'DoS',
    'Recon-PortScan': 'Recon',
    'Recon-OSScan': 'Recon',
    'Recon-HostDiscovery': 'Recon',
    'Recon-PingSweep': 'Recon',
    'VulnerabilityScan': 'Recon',
    
    'XSS': 'Web',
    'CommandInjection': 'Web',
    'Uploading_Attack': 'Web',
    'SqlInjection': 'Web',
    'Backdoor_Malware': 'Web',
    'BrowserHijacking': 'Web',
    
    'DictionaryBruteForce': 'BruteForce',
    
    'MITM-ArpSpoofing': 'Spoofing',
    'DNS_Spoofing': 'Spoofing',
    
    'Mirai-greeth_flood': 'Mirai',
    'Mirai-udpplain': 'Mirai',
    'Mirai-greip_flood': 'Mirai',
    'BenignTraffic': 'Benign'
}

# %%
df1['family'] = df1['label'].apply(lambda x: remap_labels.get(x, x))
df2['family'] = df2['label'].apply(lambda x: remap_labels.get(x, x))
df3['family'] = df3['label'].apply(lambda x: remap_labels.get(x, x))
df4['family'] = df4['label'].apply(lambda x: remap_labels.get(x, x))
df5['family'] = df5['label'].apply(lambda x: remap_labels.get(x, x))
df6['family'] = df6['label'].apply(lambda x: remap_labels.get(x, x))
df7['family'] = df7['label'].apply(lambda x: remap_labels.get(x, x))
df8['family'] = df8['label'].apply(lambda x: remap_labels.get(x, x))
df9['family'] = df9['label'].apply(lambda x: remap_labels.get(x, x))
df10['family'] = df10['label'].apply(lambda x: remap_labels.get(x, x))
df11['family'] = df11['label'].apply(lambda x: remap_labels.get(x, x))
df12['family'] = df12['label'].apply(lambda x: remap_labels.get(x, x))
df13['family'] = df13['label'].apply(lambda x: remap_labels.get(x, x))
df14['family'] = df14['label'].apply(lambda x: remap_labels.get(x, x))
df15['family'] = df15['label'].apply(lambda x: remap_labels.get(x, x))
df16['family'] = df16['label'].apply(lambda x: remap_labels.get(x, x))

# %%
df7['family'].value_counts()
# Out:
# DDoS          170524
# DoS            40242
# Mirai          13088
# Benign          5537
# Spoofing        2503
# Recon           1750
# Web               95
# BruteForce        54
# Name: family, dtype: int64

# %%
df = pd.concat([df1, df2], axis=0)
df = pd.concat([df, df3], axis=0)
df = pd.concat([df, df5], axis=0)
df = pd.concat([df, df6], axis=0)
df = pd.concat([df, df7], axis=0)
df = pd.concat([df, df8], axis=0)
df = pd.concat([df, df9], axis=0)
df = pd.concat([df, df10], axis=0)
df = pd.concat([df, df11], axis=0)
df = pd.concat([df, df12], axis=0)
df = pd.concat([df, df13], axis=0)
df = pd.concat([df, df14], axis=0)
df = pd.concat([df, df15], axis=0)
df = pd.concat([df, df16], axis=0)

# %%
df.head()
# Out:
#    flow_duration  Header_Length  Protocol Type  Duration         Rate  \
# 0       0.000000          54.00           6.00     64.00     0.329807
# 1       0.000000          57.04           6.33     64.00     4.290556
# 2       0.000000           0.00           1.00     64.00    33.396799
# 3       0.328175       76175.00          17.00     64.00  4642.133010
# 4       0.117320         101.73           6.11     65.91     6.202211
#
#          Srate  Drate  fin_flag_number  syn_flag_number  rst_flag_number  ...  \
# 0     0.329807    0.0              1.0              0.0              1.0  ...
# 1     4.290556    0.0              0.0              0.0              0.0  ...
# 2    33.396799    0.0              0.0              0.0              0.0  ...
# 3  4642.133010    0.0              0.0              0.0              0.0  ...
# 4     6.202211    0.0              0.0              1.0              0.0  ...
#
#    Tot size           IAT  Number   Magnitue     Radius   Covariance  \
# ...

# %%
df['family'].value_counts()
# Out:
# DDoS          2599859
# DoS            618129
# Mirai          201185
# Benign          84398
# Spoofing        37431
# Recon           27159
# Web              1859
# BruteForce        957
# Name: family, dtype: int64

# %%
df.to_csv("dataset.csv", encoding='utf-8', index=False)

# %%
import pandas as pd
df=pd.read_csv("dataset.csv")

# %%
df.head()
# Out:
#    flow_duration  Header_Length  Protocol Type  Duration         Rate  \
# 0       0.000000          54.00           6.00     64.00     0.329807
# 1       0.000000          57.04           6.33     64.00     4.290556
# 2       0.000000           0.00           1.00     64.00    33.396799
# 3       0.328175       76175.00          17.00     64.00  4642.133010
# 4       0.117320         101.73           6.11     65.91     6.202211
#
#          Srate  Drate  fin_flag_number  syn_flag_number  rst_flag_number  ...  \
# 0     0.329807    0.0              1.0              0.0              1.0  ...
# 1     4.290556    0.0              0.0              0.0              0.0  ...
# 2    33.396799    0.0              0.0              0.0              0.0  ...
# 3  4642.133010    0.0              0.0              0.0              0.0  ...
# 4     6.202211    0.0              0.0              1.0              0.0  ...
#
#    Tot size           IAT  Number   Magnitue     Radius   Covariance  \
# ...

# %%
balanced_df = df.groupby('family', group_keys=False).apply(lambda x: x.sample(min(len(x), 1000)))

# %%
balanced_df['family'].value_counts()
# Out:
# DoS           1000
# Web           1000
# Spoofing      1000
# Mirai         1000
# Recon         1000
# Benign        1000
# DDoS          1000
# BruteForce     957
# Name: family, dtype: int64

# %%
balanced_df.to_csv("balanced_dataset.csv", encoding='utf-8', index=False)

# %%
balanced_df.label.value_counts()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=3a3c41eb-c99a-4899-842d-6de17d10af25' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
